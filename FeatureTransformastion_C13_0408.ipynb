# %% [markdown]
# # Feature Transformation

# %%
Quick review of how to interprete information about data from the .describe() function:

# %%
# Load CSV using NumPy
from numpy import loadtxt
filename =  "C:/Users/stanl/Documents/dataset/diabetes .csv"   #' 'c:/dataset/master/pima-indians-diabetes.data.csv'
raw_data = open(filename, 'rb')
data = loadtxt(raw_data, delimiter=",")
print(data.shape)

# %% [markdown]
# #### Load CSV Files with Pandas

# %%
# Load CSV using Pandas
from pandas import read_csv
##filename = "C:/Users/stanl/Documents/dataset/diabetes.csv"      #   'c:/dataset/master/pima-indians-diabetes.data.csv'
#names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
filename = "/Users/damilolaolaoba/Documents/ONE CAMPUS/diabetes.csv.csv"
data = read_csv(filename)
print(data.shape)
# Out:
# (1000, 14)

# %%
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
#checks for missing value
data.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
#checks the structure of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
set(data.Gender.values)
# Out:
# {'F', 'M', 'f'}

# %%
#data[data['Gender']== 'F']

# %%
data.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
#Normalization....2nd
##NORMAL DISTRIBUTION CHECK
#check the minimum and maximum value and determine the middle point
#check the 50th percentile...should be as close to that middle point
#compare 50th percentile value to the mean of that feature
#E.G Urea
data.Urea.plot(kind = 'density') ###not normal...we need to normalize the data
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.HbA1c.plot(kind = 'density') ##near normal
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.AGE.plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#rescaling...1st
#compare the minimum value and maximum value for each feature
#if the scales are widely far apart across our data, we need to rescale
#what rescaling does is that it divides all the value in the feature by the maximum value
#such that that the minimum and maximum value is 0 amd 1 respectively!
#DO NOT RESCALE THE OUTCOME VARIABLE!!!

# %%
#standardization....3rd
#when the standard deviation across our data are wide apart across our data
#we need to standardize our data

# %%
#check colöumns in data
data.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
newData = data.loc[:,['ID', 'No_Pation', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
       'HDL', 'LDL', 'VLDL', 'BMI']]
newData
# Out:
#       ID  No_Pation  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 0    502      17975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1    735      34221   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2    420      47975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3    680      87656   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4    504      34223   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..   ...        ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995  200     454317   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996  671     876534   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997  669      87654   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998   99      24004   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999  248      24054   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
# [1000 rows x 12 columns]

# %%
#df

# %%
#df.values

# %%
#Rescaling Data

# Rescale data (between 0 and 1)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

dataframe = newData
array = dataframe.values
# separate array into input and output components
X = array[:,0:11]
Y = array[:,11]
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)
# summarize transformed data
set_printoptions(precision=3)

print(rescaledX[0:5,:])
# Out:
# [[6.270e-01 2.367e-04 5.085e-01 1.094e-01 5.038e-02 2.649e-01 4.078e-01
#   4.444e-02 2.268e-01 1.146e-01 1.146e-02]
#  [9.186e-01 4.520e-04 1.017e-01 1.042e-01 7.053e-02 2.649e-01 3.592e-01
#   8.148e-02 9.278e-02 1.875e-01 1.433e-02]
#  [5.244e-01 6.343e-04 5.085e-01 1.094e-01 5.038e-02 2.649e-01 4.078e-01
#   4.444e-02 2.268e-01 1.146e-01 1.146e-02]
#  [8.498e-01 1.160e-03 5.085e-01 1.094e-01 5.038e-02 2.649e-01 4.078e-01
#   4.444e-02 2.268e-01 1.146e-01 1.146e-02]
#  [6.295e-01 4.520e-04 2.203e-01 1.719e-01 5.038e-02 2.649e-01 4.757e-01
#   5.185e-02 6.186e-02 1.771e-01 8.596e-03]]

# %%
import pandas as pd 
newDF = pd.DataFrame(rescaledX)
newDF
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.627034  0.000237  0.508475  0.109375  0.050378  0.264901  0.407767
# 1    0.918648  0.000452  0.101695  0.104167  0.070529  0.264901  0.359223
# 2    0.524406  0.000634  0.508475  0.109375  0.050378  0.264901  0.407767
# 3    0.849812  0.001160  0.508475  0.109375  0.050378  0.264901  0.407767
# 4    0.629537  0.000452  0.220339  0.171875  0.050378  0.264901  0.475728
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.249061  0.006021  0.864407  0.273438  0.114610  0.403974  0.728155
# 996  0.838548  0.011618  0.186441  0.065104  0.068010  0.754967  0.398058
# 997  0.836045  0.001160  0.169492  0.171875  0.094458  0.384106  0.398058
# 998  0.122653  0.000317  0.305085  0.138021  0.066751  0.384106  0.514563
# 999  0.309136  0.000317  0.576271  0.117188  0.076826  0.397351  0.368932
#
#            7         8         9         10
# ...

# %%
newDF.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.424906     0.003585     0.568271     0.120436     0.079273
# std       0.300873     0.044817     0.149140     0.076437     0.075548
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.156133     0.000317     0.525424     0.083333     0.052897
# 50%       0.374844     0.000454     0.593220     0.106771     0.068010
# 75%       0.687422     0.000600     0.661017     0.135417     0.084383
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.488819     0.472118     0.151823     0.103582     0.240603
# std       0.167815     0.126382     0.103791     0.068084     0.116156
# ...

# %%
newDF.columns = ['ID', 'No_Pation', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
       'HDL', 'LDL', 'VLDL', 'BMI']

newDF
# Out:
#            ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol  \
# 0    0.627034   0.000237  0.508475  0.109375  0.050378  0.264901  0.407767
# 1    0.918648   0.000452  0.101695  0.104167  0.070529  0.264901  0.359223
# 2    0.524406   0.000634  0.508475  0.109375  0.050378  0.264901  0.407767
# 3    0.849812   0.001160  0.508475  0.109375  0.050378  0.264901  0.407767
# 4    0.629537   0.000452  0.220339  0.171875  0.050378  0.264901  0.475728
# ..        ...        ...       ...       ...       ...       ...       ...
# 995  0.249061   0.006021  0.864407  0.273438  0.114610  0.403974  0.728155
# 996  0.838548   0.011618  0.186441  0.065104  0.068010  0.754967  0.398058
# 997  0.836045   0.001160  0.169492  0.171875  0.094458  0.384106  0.398058
# 998  0.122653   0.000317  0.305085  0.138021  0.066751  0.384106  0.514563
# 999  0.309136   0.000317  0.576271  0.117188  0.076826  0.397351  0.368932
#
#            TG       HDL       LDL      VLDL       BMI
# ...

# %%
newDF.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.424906     0.003585     0.568271     0.120436     0.079273
# std       0.300873     0.044817     0.149140     0.076437     0.075548
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.156133     0.000317     0.525424     0.083333     0.052897
# 50%       0.374844     0.000454     0.593220     0.106771     0.068010
# 75%       0.687422     0.000600     0.661017     0.135417     0.084383
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8            9   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.488819     0.472118     0.151823     0.103582     0.240603
# std       0.167815     0.126382     0.103791     0.068084     0.116156
# ...

# %%
newDF.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
newDF['Class'] = df['CLASS']

# %%
X
# Out:
# array([[0.6270337922403003, 0.0002366523977943869, 0.5084745762711864,
#         ..., 0.11458333333333334, 0.011461318051575933,
#         0.17391304347826098],
#        [0.918648310387985, 0.00045201509410671103, 0.1016949152542373,
#         ..., 0.18750000000000003, 0.014326647564469913,
#         0.13913043478260878],
#        [0.5244055068836044, 0.0006343429609711518, 0.5084745762711864,
#         ..., 0.11458333333333334, 0.011461318051575933,
#         0.17391304347826098],
#        ...,
#        [0.8360450563204005, 0.0011603417561808472, 0.1694915254237288,
#         ..., 0.21875, 0.22922636103151864, 0.2921739130434783],
#        [0.12265331664580725, 0.00031657494464081075, 0.30508474576271183,
#         ..., 0.2708333333333333, 0.39828080229226365, 0.7478260869565219],
#        [0.3091364205256571, 0.00031723776224610537, 0.576271186440678,
#         ..., 0.28125, 0.017191977077363897, 0.4869565217391305]],
#       dtype=object)

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from pandas import read_csv
from numpy import set_printoptions
 
array = newDF.values
# separate array into input and output components
X = array[:,0:12]
#Y = array[:,12]
scaler = Normalizer().fit(X)  #normalize
normalizedX = scaler.transform(X) #transform
# summarize transformed data
set_printoptions(precision=3)   #reduces number of decimal places
print(normalizedX[0:5,:])
# Out:
# [[6.369e-01 2.404e-04 5.165e-01 1.111e-01 5.117e-02 2.691e-01 4.142e-01
#   4.514e-02 2.304e-01 1.164e-01 1.164e-02]
#  [8.681e-01 4.271e-04 9.610e-02 9.843e-02 6.665e-02 2.503e-01 3.394e-01
#   7.700e-02 8.768e-02 1.772e-01 1.354e-02]
#  [5.684e-01 6.876e-04 5.511e-01 1.186e-01 5.460e-02 2.871e-01 4.420e-01
#   4.817e-02 2.458e-01 1.242e-01 1.242e-02]
#  [7.458e-01 1.018e-03 4.462e-01 9.599e-02 4.421e-02 2.325e-01 3.579e-01
#   3.901e-02 1.990e-01 1.006e-01 1.006e-02]
#  [6.989e-01 5.018e-04 2.446e-01 1.908e-01 5.593e-02 2.941e-01 5.281e-01
#   5.756e-02 6.867e-02 1.966e-01 9.543e-03]]

# %%
normalizedX_df= pd.DataFrame(normalizedX, columns =['ID', 'No_Pation', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
       'HDL', 'LDL', 'VLDL'])
normalizedX_df
# Out:
#            ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol  \
# 0    0.636873   0.000240  0.516453  0.111091  0.051168  0.269057  0.414165
# 1    0.868078   0.000427  0.096097  0.098432  0.066646  0.250318  0.339449
# 2    0.568406   0.000688  0.551139  0.118552  0.054605  0.287127  0.441981
# 3    0.745808   0.001018  0.446245  0.095989  0.044212  0.232481  0.357862
# 4    0.698890   0.000502  0.244613  0.190810  0.055928  0.294083  0.528137
# ..        ...        ...       ...       ...       ...       ...       ...
# 995  0.194688   0.004706  0.675694  0.213742  0.089589  0.315780  0.569188
# 996  0.636094   0.008813  0.141428  0.049386  0.051590  0.572692  0.301953
# 997  0.767470   0.001065  0.155589  0.157777  0.086711  0.352600  0.365408
# 998  0.136063   0.000351  0.338439  0.153110  0.074048  0.426100  0.570820
# 999  0.337286   0.000346  0.628745  0.127858  0.083822  0.433533  0.402526
#
#            TG       HDL       LDL      VLDL
# ...

# %%
normalizedX_df.describe()
# Out:
#                 ID    No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.363567     0.002803     0.514494     0.110393     0.072325
# std       0.231476     0.031670     0.131268     0.067031     0.057098
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.157633     0.000301     0.446972     0.071723     0.046529
# 50%       0.347142     0.000382     0.520282     0.096248     0.062302
# 75%       0.562512     0.000564     0.601296     0.128093     0.079749
# max       0.868078     0.706346     0.893836     0.722834     0.691717
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.437353     0.428822     0.136174     0.095459     0.219005
# std       0.124637     0.106727     0.084211     0.057537     0.099979
# ...

# %%
normDF.AGE.plot(kind='density'

# %%
normalizedX_df.AGE.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#newDF.AGE.plot(kind='density')
#pipelining
#rescale first
#then normalize...always normalize
#then standardize...this is hardly necessary

# %% [markdown]
# ### Prepare Your Data For Machine Learning

# %% [markdown]
# #####
# Many machine learning algorithms make assumptions about your data.
# For this reason we need to ensure data is prepared in a way that best
# exposes the structure of the problem to the machine learning algorithms we intend to use.
#
# Some of the popular data transformation tachniques are;
#
# 1. Rescale data.
# 2. Standardize data.
# 3. Normalize data.
# 4. Binarize data

# %%
df
# Out:
#       ID  No_Pation  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0    502      17975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1    735      34221   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2    420      47975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3    680      87656   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4    504      34223   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..   ...        ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995  200     454317   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996  671     876534   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997  669      87654   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998   99      24004   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999  248      24054   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#     CLASS
# 0       N
# 1       N
# 2       N
# 3       N
# ...

# %% [markdown]
# #####
# Data Transforms
#
# . Split the dataset into the input and output variables for machine learning.
# . Apply a pre-processing transform to the input variables.
# . Summarize the data to show the change.
#
#
# The scikit-learn library provides two standard idioms for transforming data.
# Each are useful in different circumstances.
#
# The transforms are calculated in such a way that they can be applied
# to your training data and any samples of data you may have in the future.
#
# . Fit and Multiple Transform.
# . Combined Fit-And-Transform.
#
# The Fit and Multiple Transform method is the preferred approach.
# You call the fit() function to prepare the parameters of the transform
# once on your data.
# Then later you can use the transform() function on the same data to prepare it for modeling and again on the test or
# validation dataset or new data that you may see in the future.
#
# The Combined Fit-And-Transform is a convenience that you can use for one off tasks.
# This might be useful if you are interested in plotting or summarizing the transformed data.

# %% [markdown]
# ### Rescale Data

# %% [markdown]
# ######
# When your data is comprised of attributes with varying scales, This can impact the performance of
# most machine learning algorithms.
#
# Rescaling forces attributes to all have the same scale.
# Often this is referred to as normalization and attributes are often rescaled into the range between 0 and 1.
#
# Recaling is valuable for:
#
# 1. optimization algorithms like gradient descent.
#
# 2. algorithms that weight inputs like regression and neural networks
#
# 3. algorithms that use distance measures like k-Nearest Neighbors.
#
# Rescale your data using scikit-learn (MinMaxScaler)

# %%
# Rescale data (between 0 and 1)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
filename = 'c:/dataset/master/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX = scaler.fit_transform(X)
# summarize transformed data
set_printoptions(precision=3)

print(rescaledX[0:5,:])

# %% [markdown]
# ### Standardize Data

# %% [markdown]
# #####
# Standardization is used to transform attributes with a Gaussian distribution
# and differing means and standard deviations to a standard Gaussian distribution with a mean of
# 0 and a standard deviation of 1.
#
# It is most suitable for techniques that assume a Gaussian distribution in the input variables.
# It works better with rescaled data,
#
# Algorithms that benefit from standardization:
#
# Linear regression,
# logistic regression
# linear discriminate analysis.
#
# Standardize data using scikit-learn with the StandardScaler

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler
from pandas import read_csv
from numpy import set_printoptions
filename = 'c:/dataset/master/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(rescaledX[0:5,:])

# %% [markdown]
# ### Normalize Data

# %% [markdown]
# ####
# Normalizing in scikit-learn refers to rescaling each observation (row) to have a length of 1
# (called a unit norm or a vector with the length of 1 in linear algebra).
#
# This pre-processing method can be useful for sparse datasets (lots of zeros) with attributes of varying
# scales when using algorithms that weight input values such as neural networks and algorithms that use distance
# measures such as k-Nearest Neighbors.
#
# You can normalize data in Python with scikit-learn using the Normalizer

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from pandas import read_csv
from numpy import set_printoptions
'''filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)'''
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
Y = array[:,8]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(normalizedX[0:5,:])

# %% [markdown]
# ### Binarize Data (Make Binary)

# %% [markdown]
# ######
# You can transform your data using a binary threshold.
# All values above the threshold are marked 1
# and allvalues equal to or below 1 are marked as 0.
# This is called binarizing your data or thresholding your data.
# It can be useful when you have probabilities that you want to transform into crisp values.
# It is also useful when doing feature engineering to add new meaningful features

# %%
# binarization
from sklearn.preprocessing import Binarizer
from pandas import read_csv

from numpy import set_printoptions
filename = 'c:/dataset/master/pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
# separate array into input and output components
X = array[:,0:8]
 
Y = array[:,8]
binarizer = Binarizer(threshold=0.0).fit(X)
binaryX = binarizer.transform(X)
# summarize transformed data
set_printoptions(precision=3)
print(binaryX[0:5,:])

# %%
What we have covered:
    
. Rescale data.
. Standardize data.
. Normalize data.
. Binarize data.

You now know how to transform your data to best expose the structure of your problem to the
modeling algorithms.
